# %%
# %run ../../../utils/commonImports.py
# %run ../../../utils/tradingImports.py
# %matplotlib inline

from base import supres
from exputils import *

# %% [markdown]
# # Load data

# %%
# dropbox_dir = 'D:\\Dropbox\\My work\\krypl-project'
dropbox_dir = '/Users/david.vesely/Dropbox/My work/krypl-project'
features = ['support']
pairs = read_tsv('selected-pairs.tsv', header=None)[0].tolist()

data_dict = {p: read_all(p, dropbox_dir) for p in pairs}

# %% [markdown]
# # Calculate Supports

# %%
window_sizes = [4]

# %%
from tqdm import tqdm_notebook

n = len(pairs) * len(window_sizes)
with tqdm_notebook(total=n) as pbar:
    supports_data = pd.DataFrame()
    for pair in pairs:
        for win_size in window_sizes:
            data = data_dict[pair]
            supports, _ = supres(data['ohlc4'], win_size)
            supports_df = pd.DataFrame(supports, columns=['index', 'support'])
            supports_df['pair'] = pair
            supports_df['win_size'] = win_size
            supports_df['date'] = data['date'].iloc[supports_df['index']].tolist()
            supports_data = supports_data.append(supports_df)
            pbar.update()
# Out:
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))

# %%
write_tsv(supports_data, 'supports.tsv')

# %%
supports_data
# Out:
#            index  support     pair  win_size                 date
# 0        24.0000   0.0021  BTC_ETH         4  2016-01-01 12:00:00
# 1        33.0000   0.0022  BTC_ETH         4  2016-01-01 16:30:00
# 2        45.0000   0.0022  BTC_ETH         4  2016-01-01 22:30:00
# 3        58.0000   0.0022  BTC_ETH         4  2016-01-02 05:00:00
# 4        70.0000   0.0022  BTC_ETH         4  2016-01-02 11:00:00
# 5        84.0000   0.0022  BTC_ETH         4  2016-01-02 18:00:00
# 6        94.0000   0.0022  BTC_ETH         4  2016-01-02 23:00:00
# 7        99.0000   0.0022  BTC_ETH         4  2016-01-03 01:30:00
# 8       107.0000   0.0022  BTC_ETH         4  2016-01-03 05:30:00
# 9       112.0000   0.0022  BTC_ETH         4  2016-01-03 08:00:00
# 10      122.0000   0.0023  BTC_ETH         4  2016-01-03 13:00:00
# 11      129.0000   0.0023  BTC_ETH         4  2016-01-03 16:30:00
# 12      140.0000   0.0022  BTC_ETH         4  2016-01-03 22:00:00
# 13      154.0000   0.0022  BTC_ETH         4  2016-01-04 05:00:00
# 14      160.0000   0.0022  BTC_ETH         4  2016-01-04 08:00:00
# 15      176.0000   0.0022  BTC_ETH         4  2016-01-04 16:00:00
# 16      181.0000   0.0021  BTC_ETH         4  2016-01-04 18:30:00
# 17      196.0000   0.0022  BTC_ETH         4  2016-01-05 02:00:00
# 18      206.0000   0.0022  BTC_ETH         4  2016-01-05 07:00:00
# 19      214.0000   0.0022  BTC_ETH         4  2016-01-05 11:00:00
# 20      226.0000   0.0022  BTC_ETH         4  2016-01-05 17:00:00
# 21      234.0000   0.0022  BTC_ETH         4  2016-01-05 21:00:00
# 22      238.0000   0.0022  BTC_ETH         4  2016-01-05 23:00:00
# 23      247.0000   0.0022  BTC_ETH         4  2016-01-06 03:30:00
# 24      254.0000   0.0022  BTC_ETH         4  2016-01-06 07:00:00
# 25      259.0000   0.0022  BTC_ETH         4  2016-01-06 09:30:00
# 26      269.0000   0.0022  BTC_ETH         4  2016-01-06 14:30:00
# 27      279.0000   0.0022  BTC_ETH         4  2016-01-06 19:30:00
# 28      283.0000   0.0022  BTC_ETH         4  2016-01-06 21:30:00
# 29      303.0000   0.0021  BTC_ETH         4  2016-01-07 07:30:00
# ...          ...      ...      ...       ...                  ...
# 5245 56,522.0000   0.0000  BTC_XPM         4  2019-03-23 13:00:00
# 5246 56,528.0000   0.0000  BTC_XPM         4  2019-03-23 16:00:00
# 5247 56,542.0000   0.0000  BTC_XPM         4  2019-03-23 23:00:00
# 5248 56,550.0000   0.0000  BTC_XPM         4  2019-03-24 03:00:00
# 5249 56,557.0000   0.0000  BTC_XPM         4  2019-03-24 06:30:00
# 5250 56,561.0000   0.0000  BTC_XPM         4  2019-03-24 08:30:00
# 5251 56,574.0000   0.0000  BTC_XPM         4  2019-03-24 15:00:00
# 5252 56,579.0000   0.0000  BTC_XPM         4  2019-03-24 17:30:00
# 5253 56,585.0000   0.0000  BTC_XPM         4  2019-03-24 20:30:00
# 5254 56,590.0000   0.0000  BTC_XPM         4  2019-03-24 23:00:00
# 5255 56,599.0000   0.0000  BTC_XPM         4  2019-03-25 03:30:00
# 5256 56,613.0000   0.0000  BTC_XPM         4  2019-03-25 10:30:00
# 5257 56,623.0000   0.0000  BTC_XPM         4  2019-03-25 15:30:00
# 5258 56,643.0000   0.0000  BTC_XPM         4  2019-03-26 01:30:00
# 5259 56,660.0000   0.0000  BTC_XPM         4  2019-03-26 10:00:00
# 5260 56,701.0000   0.0000  BTC_XPM         4  2019-03-27 06:30:00
# 5261 56,711.0000   0.0000  BTC_XPM         4  2019-03-27 11:30:00
# 5262 56,722.0000   0.0000  BTC_XPM         4  2019-03-27 17:00:00
# 5263 56,755.0000   0.0001  BTC_XPM         4  2019-03-28 09:30:00
# 5264 56,769.0000   0.0001  BTC_XPM         4  2019-03-28 16:30:00
# 5265 56,782.0000   0.0001  BTC_XPM         4  2019-03-28 23:00:00
# 5266 56,798.0000   0.0001  BTC_XPM         4  2019-03-29 07:00:00
# 5267 56,806.0000   0.0001  BTC_XPM         4  2019-03-29 11:00:00
# 5268 56,827.0000   0.0001  BTC_XPM         4  2019-03-29 21:30:00
# 5269 56,838.0000   0.0001  BTC_XPM         4  2019-03-30 03:00:00
# 5270 56,850.0000   0.0001  BTC_XPM         4  2019-03-30 09:00:00
# 5271 56,865.0000   0.0001  BTC_XPM         4  2019-03-30 16:30:00
# 5272 56,899.0000   0.0001  BTC_XPM         4  2019-03-31 09:30:00
# 5273 56,916.0000   0.0001  BTC_XPM         4  2019-03-31 18:00:00
# 5274 56,924.0000   0.0001  BTC_XPM         4  2019-03-31 22:00:00
#
# [104605 rows x 5 columns]
