# %%
# %run ../../utils/commonImports.py
# %run ../../utils/tradingImports.py
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_split("D:\\Dropbox\\My work\\krypl-project\\dataSplit\\return-01-loss-max-01-within-day")

# %%
data = X_train.copy()
data['label'] = y_train.copy()
data = data.sample(10**4)
data.shape
# Out:
# (10000, 24)

# %% [markdown]
# # Scatter Matrix

# %%
columns = list(data.columns[:-1])
for i in range(0, len(columns), 3):
    selected = columns[i:i+3] + ['label']
    sns.pairplot(data[selected], hue='label', hue_order=[0, 1], vars=selected, plot_kws={'alpha': 0.3})
