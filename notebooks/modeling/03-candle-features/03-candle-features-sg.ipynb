# %%
# %run ../../utils/commonImports.py
# %matplotlib inline

# %% [markdown]
# # Load data

# %%
featured = read_tsv('D:\\Dropbox\\My work\\krypl-project\\dataFeatures\\candle-shape-sg.tsv')
featured.tail()
# Out:
#          timestamp period       open       high        low      close  \
# 381237  1538744100   5min 6,589.1520 6,594.8563 6,589.1520 6,594.8563
# 381238  1538744400   5min 6,589.9249 6,594.9835 6,589.9249 6,594.9835
# 381239  1538744700   5min 6,590.1520 6,594.9173 6,590.1520 6,594.9173
# 381240  1538745000   5min 6,594.0000 6,595.0000 6,594.0000 6,595.0000
# 381241  1538745300   5min 6,595.1000 6,595.9343 6,595.1000 6,595.9343
#
#            volume  quoteVolume  weightedAverage                 date  \
# 381237   624.8332       0.0948       6,591.3772  2018-10-05 12:55:00
# 381238 7,250.7049       1.1001       6,590.6590  2018-10-05 13:00:00
# 381239   603.4239       0.0915       6,592.2003  2018-10-05 13:05:00
# 381240 1,476.3254       0.2239       6,594.0279  2018-10-05 13:10:00
# 381241   386.2321       0.0586       6,595.3626  2018-10-05 13:15:00
#
#                       ...                 low_high_ratio_zscore288_lag_9  \
# 381237                ...                                         1.3096
# 381238                ...                                         1.4325
# 381239                ...                                         1.4317
# 381240                ...                                         1.2321
# 381241                ...                                         0.5166
#
#         open_close_ratio_zscore288_lag_1  open_close_ratio_zscore288_lag_2  \
# 381237                            0.2662                            0.4483
# 381238                           -0.6262                            0.2662
# 381239                           -1.3237                           -0.6262
# 381240                           -1.8785                           -1.3237
# 381241                           -1.8653                           -1.8785
#
#         open_close_ratio_zscore288_lag_3  open_close_ratio_zscore288_lag_4  \
# 381237                            0.6937                            0.8870
# 381238                            0.4483                            0.6937
# 381239                            0.2662                            0.4483
# 381240                           -0.6262                            0.2662
# 381241                           -1.3237                           -0.6262
#
#         open_close_ratio_zscore288_lag_5  open_close_ratio_zscore288_lag_6  \
# 381237                            1.2439                            0.4140
# 381238                            0.8870                            1.2439
# 381239                            0.6937                            0.8870
# 381240                            0.4483                            0.6937
# 381241                            0.2662                            0.4483
#
#         open_close_ratio_zscore288_lag_7  open_close_ratio_zscore288_lag_8  \
# 381237                           -0.1762                           -0.2709
# 381238                            0.4140                           -0.1762
# 381239                            1.2439                            0.4140
# 381240                            0.8870                            1.2439
# 381241                            0.6937                            0.8870
#
#         open_close_ratio_zscore288_lag_9
# 381237                           -0.4465
# 381238                           -0.2709
# 381239                           -0.1762
# 381240                            0.4140
# 381241                            1.2439
#
# [5 rows x 55 columns]

# %%
featured['label'] = featured['label'].apply(int)

# %% [markdown]
# # Scatter matrix

# %%
featured.columns
# Out:
# Index(['timestamp', 'period', 'open', 'high', 'low', 'close', 'volume',
#        'quoteVolume', 'weightedAverage', 'date', 'label', 'open_w10_deg1',
#        'high_w10_deg1', 'low_w10_deg1', 'close_w10_deg1',
#        'close_high_ratio_zscore288', 'open_high_ratio_zscore288',
#        'low_high_ratio_zscore288', 'open_close_ratio_zscore288',
#        'close_high_ratio_zscore288_lag_1', 'close_high_ratio_zscore288_lag_2',
#        'close_high_ratio_zscore288_lag_3', 'close_high_ratio_zscore288_lag_4',
#        'close_high_ratio_zscore288_lag_5', 'close_high_ratio_zscore288_lag_6',
#        'close_high_ratio_zscore288_lag_7', 'close_high_ratio_zscore288_lag_8',
#        'close_high_ratio_zscore288_lag_9', 'open_high_ratio_zscore288_lag_1',
#        'open_high_ratio_zscore288_lag_2', 'open_high_ratio_zscore288_lag_3',
#        'open_high_ratio_zscore288_lag_4', 'open_high_ratio_zscore288_lag_5',
#        'open_high_ratio_zscore288_lag_6', 'open_high_ratio_zscore288_lag_7',
#        'open_high_ratio_zscore288_lag_8', 'open_high_ratio_zscore288_lag_9',
#        'low_high_ratio_zscore288_lag_1', 'low_high_ratio_zscore288_lag_2',
#        'low_high_ratio_zscore288_lag_3', 'low_high_ratio_zscore288_lag_4',
#        'low_high_ratio_zscore288_lag_5', 'low_high_ratio_zscore288_lag_6',
#        'low_high_ratio_zscore288_lag_7', 'low_high_ratio_zscore288_lag_8',
#        'low_high_ratio_zscore288_lag_9', 'open_close_ratio_zscore288_lag_1',
#        'open_close_ratio_zscore288_lag_2', 'open_close_ratio_zscore288_lag_3',
#        'open_close_ratio_zscore288_lag_4', 'open_close_ratio_zscore288_lag_5',
#        'open_close_ratio_zscore288_lag_6', 'open_close_ratio_zscore288_lag_7',
#        'open_close_ratio_zscore288_lag_8', 'open_close_ratio_zscore288_lag_9'],
#       dtype='object')

# %%
cols = ['label', 'close_high_ratio_zscore288', 'open_high_ratio_zscore288', 
        'low_high_ratio_zscore288', 'open_close_ratio_zscore288']
sampled = dropna(featured).query("date > '2016-06-01' and date < '2017-09-15'").sample(10**4)
sns.pairplot(sampled[cols], hue='label', hue_order=[0, 1], vars=cols, plot_kws={'alpha': 0.3});

# %% [markdown]
# # Close high ratio

# %%
cols = ['label', 'close_high_ratio_zscore288_lag_1', 'close_high_ratio_zscore288_lag_2',
       'close_high_ratio_zscore288_lag_3', 'close_high_ratio_zscore288_lag_4',
       'close_high_ratio_zscore288_lag_5', 'close_high_ratio_zscore288_lag_6',
       'close_high_ratio_zscore288_lag_7', 'close_high_ratio_zscore288_lag_8',
       'close_high_ratio_zscore288_lag_9']
sampled = featured.query("date > '2016-06-01' and date < '2017-09-15'").sample(10**4)
sns.pairplot(dropna(sampled[cols]), hue='label', hue_order=[0, 1], vars=cols, plot_kws={'alpha': 0.3});

# %% [markdown]
# # Open close ratio

# %%
cols = ['label', 'open_close_ratio_zscore288_lag_1',
       'open_close_ratio_zscore288_lag_2', 'open_close_ratio_zscore288_lag_3',
       'open_close_ratio_zscore288_lag_4', 'open_close_ratio_zscore288_lag_5',
       'open_close_ratio_zscore288_lag_6', 'open_close_ratio_zscore288_lag_7',
       'open_close_ratio_zscore288_lag_8', 'open_close_ratio_zscore288_lag_9']
sampled = featured.query("date > '2016-06-01' and date < '2017-09-15'").sample(10**4)
sns.pairplot(dropna(sampled[cols]), hue='label', hue_order=[0, 1], vars=cols, plot_kws={'alpha': 0.3});

# %% [markdown]
# # TSNE

# %%
from sklearn.manifold import TSNE
cols = ['close_high_ratio',
       'open_high_ratio', 'low_high_ratio', 'open_close_ratio',
       'close_high_ratio_lag_1', 'close_high_ratio_lag_2',
       'close_high_ratio_lag_3', 'close_high_ratio_lag_4',
       'close_high_ratio_lag_5', 'close_high_ratio_lag_6',
       'close_high_ratio_lag_7', 'close_high_ratio_lag_8',
       'close_high_ratio_lag_9', 'open_high_ratio_lag_1',
       'open_high_ratio_lag_2', 'open_high_ratio_lag_3',
       'open_high_ratio_lag_4', 'open_high_ratio_lag_5',
       'open_high_ratio_lag_6', 'open_high_ratio_lag_7',
       'open_high_ratio_lag_8', 'open_high_ratio_lag_9',
       'low_high_ratio_lag_1', 'low_high_ratio_lag_2', 'low_high_ratio_lag_3',
       'low_high_ratio_lag_4', 'low_high_ratio_lag_5', 'low_high_ratio_lag_6',
       'low_high_ratio_lag_7', 'low_high_ratio_lag_8', 'low_high_ratio_lag_9',
       'open_close_ratio_lag_1', 'open_close_ratio_lag_2',
       'open_close_ratio_lag_3', 'open_close_ratio_lag_4',
       'open_close_ratio_lag_5', 'open_close_ratio_lag_6',
       'open_close_ratio_lag_7', 'open_close_ratio_lag_8',
       'open_close_ratio_lag_9']
sampled = featured.query("date > '2016-06-01' and date < '2017-09-15'").sample(10**3)

X_embedded = TSNE(n_components=2).fit_transform(sampled[cols])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-669244ae09e6> in <module>()
#      21 sampled = featured.query("date > '2016-06-01' and date < '2017-09-15'").sample(10**3)
#      22
# ---> 23 X_embedded = TSNE(n_components=2).fit_transform(sampled[cols])
#
# c:\users\vesely\appdata\local\conda\conda\envs\crypto\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2680         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2681             # either boolean or fancy integer index
# -> 2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
#    2684             return self._getitem_frame(key)
#
# c:\users\vesely\appdata\local\conda\conda\envs\crypto\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2724             return self._take(indexer, axis=0)
#    2725         else:
# -> 2726             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2727             return self._take(indexer, axis=1)
#    2728
#
# c:\users\vesely\appdata\local\conda\conda\envs\crypto\lib\site-packages\pandas\core\indexing.py in _convert_to_indexer(self, obj, axis, is_setter)
#    1325                 if mask.any():
#    1326                     raise KeyError('{mask} not in index'
# -> 1327                                    .format(mask=objarr[mask]))
#    1328
#    1329                 return com._values_from_object(indexer)
#
# KeyError: "['close_high_ratio' 'open_high_ratio' 'low_high_ratio' 'open_close_ratio'\n 'close_high_ratio_lag_1' 'close_high_ratio_lag_2'\n 'close_high_ratio_lag_3' 'close_high_ratio_lag_4'\n 'close_high_ratio_lag_5' 'close_high_ratio_lag_6'\n 'close_high_ratio_lag_7' 'close_high_ratio_lag_8'\n 'close_high_ratio_lag_9' 'open_high_ratio_lag_1' 'open_high_ratio_lag_2'\n 'open_high_ratio_lag_3' 'open_high_ratio_lag_4' 'open_high_ratio_lag_5'\n 'open_high_ratio_lag_6' 'open_high_ratio_lag_7' 'open_high_ratio_lag_8'\n 'open_high_ratio_lag_9' 'low_high_ratio_lag_1' 'low_high_ratio_lag_2'\n 'low_high_ratio_lag_3' 'low_high_ratio_lag_4' 'low_high_ratio_lag_5'\n 'low_high_ratio_lag_6' 'low_high_ratio_lag_7' 'low_high_ratio_lag_8'\n 'low_high_ratio_lag_9' 'open_close_ratio_lag_1' 'open_close_ratio_lag_2'\n 'open_close_ratio_lag_3' 'open_close_ratio_lag_4'\n 'open_close_ratio_lag_5' 'open_close_ratio_lag_6'\n 'open_close_ratio_lag_7' 'open_close_ratio_lag_8'\n 'open_close_ratio_lag_9'] not in index"

# %%
data_embedded = pd.DataFrame(X_embedded)
data_embedded['label'] = sampled['label'].apply(int).values

# %%
plt.figure(figsize=[12, 6])
sns.scatterplot(data_embedded[0], data_embedded[1], hue=data_embedded['label'], hue_order=[0, 1], alpha=0.3);
