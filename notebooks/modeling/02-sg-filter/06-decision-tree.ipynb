# %%
# %run ../../utils/commonImports.py
# %matplotlib inline

# %% [markdown]
# # Load Data

# %%
X_train, y_train, X_val, y_val, X_test, y_test = load_split('D:\\Dropbox\\My work\\krypl-project\\dataSplit\\02-sg-filter')

# %% [markdown]
# # Test Train Validation Split

# %%
fig, axes = plt.subplots(1, 3, figsize=[12, 4])
y_train.value_counts().plot(kind='bar', ax=axes[0])
axes[0].set_title('Train Distribution', fontproperties=title_font)
y_val.value_counts().plot(kind='bar', ax=axes[1])
axes[1].set_title('Validation Distribution', fontproperties=title_font)
y_test.value_counts().plot(kind='bar', ax=axes[2])
axes[2].set_title('Test Distribution', fontproperties=title_font);

# %%
X_train.describe()
# Out:
#        return_close_w10_deg1  return_close_w10_deg1_1  \
# count            69,289.0000              69,289.0000
# mean                  0.0000                   0.0000
# std                   0.0017                   0.0017
# min                  -0.0314                  -0.0428
# 25%                  -0.0006                  -0.0006
# 50%                   0.0000                   0.0000
# 75%                   0.0007                   0.0007
# max                   0.0417                   0.0391
#
#        return_close_w10_deg1_2  zscore_36_volume  zscore_288_volume  \
# count              69,289.0000       69,289.0000        69,289.0000
# mean                    0.0000            0.1295             0.0260
# std                     0.0017            2.1645             1.3187
# min                    -0.0518           -2.5915            -1.5648
# 25%                    -0.0006           -0.5774            -0.4571
# 50%                     0.0000           -0.3397            -0.2896
# 75%                     0.0007            0.2066             0.0845
# max                     0.0417          154.6952            97.6802
#
#        zscore_2016_volume  zscore_36_return  zscore_288_return       pma36  \
# count         69,289.0000       69,289.0000        69,289.0000 69,289.0000
# mean               0.0338           -0.0125            -0.0041     -0.0043
# std                1.1215            1.1481             1.0565      1.1166
# min               -1.2240          -24.5244           -22.3024    -12.7022
# 25%               -0.3993           -0.6853            -0.5693     -0.5791
# 50%               -0.2659            0.0111             0.0193      0.0122
# 75%                0.0709            0.6861             0.5889      0.5820
# max               45.1564           13.9913            10.7785     12.0510
#
#            pma288     pma2016   ma_12_108   ma_36_288        ac36       ac288
# count 69,289.0000 69,289.0000 69,289.0000 69,289.0000 69,289.0000 69,289.0000
# mean      -0.0028      0.0165     -0.0008     -0.0012      0.0010      0.0195
# std        1.3885      1.4335      1.2223      1.4207      1.1765      1.6964
# min      -11.6121    -12.0752     -9.9789     -9.6030     -8.7601     -5.3216
# 25%       -0.9526     -1.0073     -0.7155     -0.9918     -0.6748     -1.5310
# 50%        0.0066      0.0096     -0.0023      0.0087      0.0059      0.0311
# 75%        0.9543      1.0643      0.7244      0.9905      0.6804      1.5596
# max       10.1738     10.8004      8.6158      8.7905      7.1075      4.8356

# %% [markdown]
# # Decision Tree

# %%
import time
from modeling.gridsearch import GridSearch
from sklearn.tree import DecisionTreeClassifier

params_to_train = {
    'max_depth': [5, 8, 10, 12, 15, 18, 20, 25, 30, 35, 40],
    'min_samples_split': [2, 5, 10, 30, 50],
    'class_weight': ['balanced']
}

grid_search = GridSearch(DecisionTreeClassifier, params_to_train)
grid_search.fit_all(X_train, y_train)

path = "D:\\Dropbox\\My work\\krypl-project\\models\\02-sg-filter"
save_model(grid_search, f'{path}\\tree_search.pkl');
# Out:
# train [0/55] {'max_depth': 5, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 1.00 sec
# train [1/55] {'max_depth': 5, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 0.97 sec
# train [2/55] {'max_depth': 5, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 1.08 sec
# train [3/55] {'max_depth': 5, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 1.02 sec
# train [4/55] {'max_depth': 5, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 1.09 sec
# train [5/55] {'max_depth': 8, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 1.53 sec
# train [6/55] {'max_depth': 8, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 1.46 sec
# train [7/55] {'max_depth': 8, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 1.46 sec
# train [8/55] {'max_depth': 8, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 1.53 sec
# train [9/55] {'max_depth': 8, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 1.46 sec
# train [10/55] {'max_depth': 10, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 1.88 sec
# train [11/55] {'max_depth': 10, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 1.75 sec
# train [12/55] {'max_depth': 10, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 1.79 sec
# train [13/55] {'max_depth': 10, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 1.79 sec
# train [14/55] {'max_depth': 10, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 1.83 sec
# train [15/55] {'max_depth': 12, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 2.01 sec
# train [16/55] {'max_depth': 12, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 2.05 sec
# train [17/55] {'max_depth': 12, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 2.08 sec
# train [18/55] {'max_depth': 12, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 1.88 sec
# train [19/55] {'max_depth': 12, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 1.87 sec
# train [20/55] {'max_depth': 15, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 2.22 sec
# train [21/55] {'max_depth': 15, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 2.24 sec
# train [22/55] {'max_depth': 15, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 2.22 sec
# train [23/55] {'max_depth': 15, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 2.16 sec
# train [24/55] {'max_depth': 15, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 2.12 sec
# train [25/55] {'max_depth': 18, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 2.44 sec
# train [26/55] {'max_depth': 18, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 2.43 sec
# train [27/55] {'max_depth': 18, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 2.42 sec
# train [28/55] {'max_depth': 18, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 2.37 sec
# train [29/55] {'max_depth': 18, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 2.35 sec
# train [30/55] {'max_depth': 20, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 2.53 sec
# train [31/55] {'max_depth': 20, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 2.52 sec
# train [32/55] {'max_depth': 20, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 2.51 sec
# train [33/55] {'max_depth': 20, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 2.48 sec
# train [34/55] {'max_depth': 20, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 2.38 sec
# train [35/55] {'max_depth': 25, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 2.71 sec
# train [36/55] {'max_depth': 25, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 2.84 sec
# train [37/55] {'max_depth': 25, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 2.71 sec
# train [38/55] {'max_depth': 25, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 2.53 sec
# train [39/55] {'max_depth': 25, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 2.45 sec
# train [40/55] {'max_depth': 30, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 2.69 sec
# train [41/55] {'max_depth': 30, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 2.67 sec
# train [42/55] {'max_depth': 30, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 2.64 sec
# train [43/55] {'max_depth': 30, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 2.53 sec
# train [44/55] {'max_depth': 30, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 2.54 sec
# train [45/55] {'max_depth': 35, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 2.70 sec
# train [46/55] {'max_depth': 35, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 2.67 sec
# train [47/55] {'max_depth': 35, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 2.67 sec
# train [48/55] {'max_depth': 35, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 2.57 sec
# train [49/55] {'max_depth': 35, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 2.49 sec
# train [50/55] {'max_depth': 40, 'min_samples_split': 2, 'class_weight': 'balanced'}........................... 2.68 sec
# train [51/55] {'max_depth': 40, 'min_samples_split': 5, 'class_weight': 'balanced'}........................... 2.68 sec
# train [52/55] {'max_depth': 40, 'min_samples_split': 10, 'class_weight': 'balanced'}........................... 2.67 sec
# train [53/55] {'max_depth': 40, 'min_samples_split': 30, 'class_weight': 'balanced'}........................... 2.60 sec
# train [54/55] {'max_depth': 40, 'min_samples_split': 50, 'class_weight': 'balanced'}........................... 2.43 sec
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-7973859dba5e> in <module>()
#      13
#      14 path = "D:\\Dropbox\\My work\\krypl-project\\models\\02-sg-filter"
# ---> 15 save_model(grid_search, f'{path}\\tree_search.pkl');
#
# D:\Git projekty\krypl-project\notebooks\utils\common.py in save_model(model, file)
#      63
#      64 def save_model(model, file):
# ---> 65     joblib.dump(model, file)
#      66
#      67
#
# C:\Anaconda3\envs\crypto36\lib\site-packages\sklearn\externals\joblib\numpy_pickle.py in dump(value, filename, compress, protocol, cache_size)
#     481             NumpyPickler(f, protocol=protocol).dump(value)
#     482     elif is_filename:
# --> 483         with open(filename, 'wb') as f:
#     484             NumpyPickler(f, protocol=protocol).dump(value)
#     485     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Dropbox\\My work\\krypl-project\\models\\02-sg-filter\\tree_search.pkl'
